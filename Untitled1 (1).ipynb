# %%
a=[1,2,3,4]
b=[5,66,77,8]

# %%
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 66, 77, 8]

# %%
import numpy as np

# %%
a1=np.array(a)
b1=np.array(b)
print(a1+b1)
# Out:
# [ 6 68 80 12]

# %%
print(a1**2)
# Out:
# [ 1  4  9 16]

# %%
m=[[1,2,3],[5,6,7],[6,5,4]]

# %%
m1=np.array(m)
print(m1)
# Out:
# [[1 2 3]
#  [5 6 7]
#  [6 5 4]]

# %%
print(m1.shape)
# Out:
# (3, 3)

# %%
print(np.diagonal(m1))
# Out:
# [1 6 4]

# %%
print(np.mean(m1))
# Out:
# 4.333333333333333

# %%
print(np.median(m1))
# Out:
# 5.0

# %%
m2=[[1,2,4],[4,3,5],[8,9,7]]

# %%
m2=np.array(m2)
print(m2)
# Out:
# [[1 2 4]
#  [4 3 5]
#  [8 9 7]]

# %%
print(m2.shape)
# Out:
# (3, 3)

# %%
print(np.diagonal(m2))
# Out:
# [1 3 7]

# %%
print(np.matmul(m,m2))
# Out:
# [[33 35 35]
#  [85 91 99]
#  [58 63 77]]

# %%
print(np.linalg.det(m1))
# Out:
# -4.884981308350685e-15

# %%
print(np.linalg.inv(m1))
# Out:
# [[ 2.25179981e+15 -1.43296352e+15  8.18836296e+14]
#  [-4.50359963e+15  2.86592704e+15 -1.63767259e+15]
#  [ 2.25179981e+15 -1.43296352e+15  8.18836296e+14]]

# %%
print(np.linalg.eig(m1))
# Out:
# (array([ 1.31974022e+01, -2.19740216e+00, -6.82760113e-16]), array([[ 0.26986619,  0.51112091,  0.40824829],
#        [ 0.76111206,  0.3562053 , -0.81649658],
#        [ 0.5898141 , -0.78222324,  0.40824829]]))

# %%
x=[1,2,3,4,5]
y=[4,6,8,9,10]
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.xlabel("this is x-axis")
plt.xlabel("this is y-axis")
plt.title("anvesh's graph")
plt.plot(x,y,'r')

# %%
import pandas as pd

# %%
plt.pie(x+y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7dd7062eea40>,
# ...
#  [Text(1.0979931094961697, 0.06641634963570538, ''),
#   Text(1.068035996798755, 0.26324724033138536, ''),
#   Text(0.9413593913346188, 0.5690716091548729, ''),
#   Text(0.624871199399624, 0.9052822676717333, ''),
#   Text(0.06641630466003416, 1.097993112216696, ''),
#   Text(-0.5111955409824158, 0.9740016010662895, ''),
#   Text(-0.9740016608932586, 0.5111954269916487, ''),
#   Text(-1.0285178342961478, -0.39006546185834257, ''),
#   Text(-0.19828041594128673, -1.0819819206688024, ''),
#   Text(0.9052823408025569, -0.6248710934513162, '')])

# %%
import pandas as pd

# %%
d=pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
print(d)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
x=d['longitude']
y=d['median_house_value']
plt.plot(x,y)
